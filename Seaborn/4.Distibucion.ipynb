# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## ¿Que **`graficos o opciones`** me ofrece **`Seaborn`** para trabajar con distribuciones **datos numericos**?

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# **`Parametros`**
# - **`bins`(int):** Numero de barras.
#
# - **`cumulative`(bool):** acumula la primera barra hasta la ultima, total acumulativo.
#
# - **`stat`(str):** Trabaja con metodos estadisticos, por **(ejemplo: 'count', 'probability', 'percent', 'frequency', 'density' )**
#
# - **`multiple`(str):** Como quremos representar nuestros barras. por **(ejempolo: 'stack', 'layer', 'dodge', 'fill')**

# %%
# bins: Numero de barras
sns.histplot(data=tips, x="total_bill", bins=15, cumulative=False, hue="sex", stat="density", multiple='dodge');

# %% [markdown]
# ## ¿ Existen más **graficos** para las **distribuciones**?

# %% [markdown]
# > ### **`kdeplot`**: Es un diagrama de **densidad**
#
# - **`shade`(bool):** Sobrel la grafica.
#
# - **`bw_adjust`(int):** ajusta la parametros y la grafica que estamos utilizando.

# %%
sns.kdeplot(data=tips, x='tip', hue='sex', cumulative=False, shade=True, bw_adjust=1);

# %% [markdown]
# > ### **`ecdfplot`**: Es un diagrama **escalonado**

# %%
sns.ecdfplot(data=tips, x='tip', hue='sex', stat='count');

# %% [markdown]
# > #### **`displot`**: Analizar distribuciones. _**`displot` nos permite cambiar a distintos tipos de grafica con el parametro`kind` .**_

# %%
sns.displot(data=tips, x='tip', hue='sex', kind='hist');

# %% [markdown]
# --------
# ## Ejercicio para practicar
# #### El reto para ti es:
#
# - Usa displot, pero no con diagramas ‘hist’ ni de densidad ‘kde’, usa cualquier otro.
#
# - Usa otra segmentación por fumadores o día.

# %%
# Cargando las 5 primeras filas
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.displot(data=tips, x='tip', hue="smoker",col="size", kind="hist", stat='count', multiple="dodge", height=5, aspect=.8);

# %%
lette=dict(setosa="#9b59b6", virginica="#3498db", versicolor="#95a5a6", green="#55cc33" )

sns.displot(data=tips, x='tip', hue="day", col="day", kind="hist", kde=True, palette=lette.values()); 
plt.savefig("/home/naren/Descargas/propina.png")

# %%
tips.groupby(["sex"]).agg({"size":"sum"})
# Out:
#         size
# sex
# Male     413
# Female   214

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="day")
sns.rugplot(data=tips, x="total_bill", y="tip", hue="day");

# %% [markdown]
# - grilla de graificos con **Seaborn**

# %%
sns.pairplot(data=tips, hue='day', diag_kind="hist");

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="time")
sns.rugplot(data=tips, x="total_bill", y="tip", height=.1);

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
sns.rugplot(data=tips, x="total_bill", y="tip", height=.1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>
